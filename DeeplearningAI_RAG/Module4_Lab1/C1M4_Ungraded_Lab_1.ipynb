# %% [markdown]
# # Ungraded Lab - Exploring LLM Capabilities
#
# ---
#
# Welcome to the ungraded lab on exploring the capabilities of language model (LLM) parameters! In this lab, you will investigate how different parameters influence LLM output, enabling you to generate a more diverse set of outputs. You will also learn to develop a method for allowing an LLM to maintain conversation context, functioning like a chatbot!
#
# 1. Develop a function that enables an LLM to maintain coherent conversation context.
# 2. Explore how different parameters affect an LLM's behavior and output.

# %% [markdown]
# ---
# <h4 style="color:black; font-weight:bold;">USING THE TABLE OF CONTENTS</h4>
#
# JupyterLab provides an easy way for you to navigate through your assignment. It's located under the Table of Contents tab, found in the left panel, as shown in the picture below.
#
# ![TOC Location](images/toc.png)
#
# ---

# %% [markdown]
# # Table of Contents
# - [ 1 - Importing the Libraries](#1)
# - [ 2 - Recap on generation functions](#2)
#   - [ 2.1 `generate_with_single_input` and `generate_with_multiple_input`](#2-1)
#   - [ 2.2 Generating a kwargs with desired parameters](#2-2)
#   - [ 2.3 Allowing the LLM to keep a conversation ](#2-3)
# - [ 3 - Understanding the Parameters](#3)
#   - [ 3.1 Introduction](#3-1)
#   - [ 3.2 Nucleus Sampling - `top_p`](#3-2)
#   - [ 3.3 Top-k sampling](#3-3)
#   - [ 3.4 Temperature](#3-4)
#   - [ 3.5 Repetition penalty](#3-5)
# - [ 4 - Bonus: Creating a Simple Chatbot](#4)

# %% [markdown]
# <a id='1'></a>
# ## 1 - Importing the Libraries
#
# Run the cells below to import the necessary libraries.

# %%
import json
import random

# %%
from utils import (
    generate_with_single_input, 
    generate_with_multiple_input
)

# %% [markdown]
# <a id='2'></a>
# ## 2 - Recap on generation functions
#
#
# <a id='2-1'></a>
# ### 2.1 `generate_with_single_input` and `generate_with_multiple_input`
#
# Let's recap the generation functions you've been using throughout this course.
#
# ```Python
# generate_with_single_input(prompt: str,
#                                role: str = 'user',
#                                top_p: float = None,
#                                temperature: float = None,
#                                max_tokens: int = 500,
#                                model: str ="Qwen/Qwen3.5-9B")
#
#
# generate_with_multiple_input(messages: List[Dict],
#                                top_p: float = None,
#                                temperature: float = None,
#                                max_tokens: int = 500,
#                                model: str ="Qwen/Qwen3.5-9B")
# ```
#
# The function `generate_with_single_input` takes as input a prompt, role, top_k, temperature, max_tokens and model name. These parameters will be explored in the following sections. For now, let's focus on its inputs.

# %%
# The output is a dictionary with the role and content from the LLM call:
generate_with_single_input("Explain to me very briefly what is a Cyclotomic Polynomial. No more than 5 sentences.")
# Out:
# {'role': 'assistant',
#  'content': 'A cyclotomic polynomial, denoted as $\\Phi_n(x)$, is a special polynomial whose roots are the primitive complex $n$-th roots of unity. It is defined as the unique monic polynomial over the integers that shares no common factors with $x^n - 1$ other than those accounted for by smaller divisors of $n$. Essentially, it extracts the "new" roots appearing when moving from the $n$-th to the next level of roots of unity in the sequence. For example, $\\Phi_3(x)$ equals $x^2 + x + 1$, while $\\Phi_4(x)$ equals $x^2 + 1$. These polynomials play a fundamental role in number theory and algebra, particularly in the study of cyclic groups and the arithmetic properties of integers.'}

# %% [markdown]
# The function `generate_with_multiple_input` inputs a list of messages with the format `{'role': role, 'content': prompt}`. This function allows you to **create context**.

# %%
system_dict = {"role": 'system', 'content': 'You are a very ironic, but helpful assistant.'}
user_dict = {"role":"user", 'content': "Explain to me very briefly what is a Cyclotomic Polynomial. No more than 5 sentences."}
messages = [system_dict, user_dict]
generate_with_multiple_input(messages)
# Out:
# {'role': 'assistant',
#  'content': 'Oh, the joy of complex numbers, where we solve $\\Phi_n(x) = 0$ to find $n$-th roots of unity that stubbornly refuse to be lower-order roots. Think of it as the most elegant, irreducible polynomial in the ring of integers that specifically screams, "I am a primitive $n$-th root of unity!" Despite their beautiful symmetry, they secretly divide the infinite family of cyclotomic polynomials in a way that feels suspiciously like a mathematical conspiracy. Hence, while they are incredibly useful for factoring $x^n - 1$, they often make teachers of algebra cry tears of joy at how perfectly they fit together. Ultimately, they are just fancy fractions that happen to be whole numbers, proving once again that mathematics is full of delightful paradoxes. So, essentially, a cyclotomic polynomial is the mathematical soul of unity, stripped down to its bare, irreducible essentials.'}

# %% [markdown]
# Another way that will be largely used in this modules is to pass a **keyword dictionary** as parameters. You need to pass it as `**kwargs`

# %%
kwargs = {"prompt": "Write a poem about a flying rabbit.", 'top_p': 0.7, 'temperature': 1.4, 'max_tokens': 100}
generate_with_single_input(**kwargs)
# Out:
# {'role': 'assistant',
#  'content': 'The winter winds are sharp and deep,\nBeneath a sky of indigo blue,\nWhen velvet-soft and shadows sleep,\nA creature takes its path anew.\n\nNo broad-winged bird upon the breeze,\nNo feathers guiding, plumed or light,\nBut sideways flaps and desperate trees,\nTo catch the moon in early night.\n\nHis paws are pads for downward ground,\nHis ears are oars that sweep the air,\nHe defies logic'}

# %% [markdown]
# <a id='2-2'></a>
# ### 2.2 Generating a kwargs with desired parameters
#
# In this section, you will develop a function to generate a kwargs dictionary as above to feed into one of our generation functions. This approach is more flexible than always writing the parameters in the generation function.
#
# 1. **Function Overview:**
#    - **prompt**: Input text for the model.
#    - **temperature**: Controls randomness; lower values = more deterministic.
#    - **top_p**: Controls diversity; higher values = more varied outputs.
#    - **max_new_tokens**: Sets the maximum number of tokens in the response.

# %%
def generate_params_dict(
    prompt: str, 
    temperature: float = None, 
    role = 'user',
    top_p: float = None,
    max_tokens: int = 500,
    model: str = "Qwen/Qwen3.5-9B"
):
    """
    Call an LLM with different sampling parameters to observe their effects.
    
    Args:
        prompt: The text prompt to send to the model
        temperature: Controls randomness (lower = more deterministic)
        top_p: Controls diversity via nucleus sampling
        max_tokens: Maximum number of tokens to generate
        model: The model to use
        
    Returns:
        The LLM response
    """
    
    # Create the dictionary with the necessary parameters
    kwargs = {"prompt": prompt, 'role':role, "temperature": temperature, "top_p": top_p, "max_tokens": max_tokens, 'model': model} 


    return kwargs

# %%
kwargs = generate_params_dict("Solve 2x + 1 = 0.")
print(kwargs)
# Out:
# {'prompt': 'Solve 2x + 1 = 0.', 'role': 'user', 'temperature': None, 'top_p': None, 'max_tokens': 500, 'model': 'Qwen/Qwen3.5-9B'}

# %%
# Passing it to the LLM
result = generate_with_single_input(**kwargs)
print(result['content'])
# Out:
# To solve the linear equation $2x + 1 = 0$, follow these steps:
#
# 1.  **Isolate the term with $x$**: Subtract 1 from both sides of the equation.
#     $$2x = -1$$
#
# 2.  **Solve for $x$**: Divide both sides by 2.
#     $$x = -\frac{1}{2}$$
#
# **Answer:**
# $$x = -0.5$$

# %% [markdown]
# <a id='2-3'></a>
# ### 2.3 Allowing the LLM to keep a conversation
#
# Now let's develop a way of allowing an LLM to keep a conversation, i.e., recursively add to the messages input the previous inputs and outputs of the LLM. This allows you to work with an LLM like a chatbot. To allow this, you will work with a list of `context`.
#
# This function expects a list with a dictionary of context in the following format:
#
# ```Python
#
# context = [{"role": 'system', "content": 'You are a friendly assistant.'}, {'role': 'assistant', 'content': 'How can I help you?'}]
#
# ```
#
# Running this function will update the context list, so the context list after running
#
# ```Python
# call_llm_with_context('Recommend me two places to visit.', role = 'user', context = context)
# ```
#
# New context:
#
# ```Python
#
# context = [{"role": 'system', "content": 'You are a friendly assistant.'}, {'role': 'assistant', 'content': 'How can I help you?'}, {"role": 'user', 'content': 'Recommend me two places to visit.'}, {"role": "assistant", "content": 'Two places can be Paris and London.'}]
#
# ```

# %%
def call_llm_with_context(prompt: str, context: list,  role: str = 'user', **kwargs):
    """
    Calls a language model with the given prompt and context to generate a response.

    Parameters:
    - prompt (str): The input text prompt provided by the user.
    - role (str): The role of the participant in the conversation, e.g., "user" or "assistant".
    - context (list): A list representing the conversation history, to which the new input is added.
    - **kwargs: Additional keyword arguments for configuring the language model call (e.g., top_k, temperature).

    Returns:
    - response (str): The generated response from the language model based on the provided prompt and context.
    """

    # Append the dictionary {'role': role, 'content': prompt} into the context list
    context.append({'role': role, 'content': prompt})

    # Call the llm with multiple input passing the context list and the **kwargs
    response = generate_with_multiple_input(context, **kwargs)

    # Append the LLM response in the context dict
    context.append(response) 
    
    return response

# %%
# Example usage
context = [{"role": 'system', 'content': 'You are an ironic but helpful assistant.'}, 
           {'role': 'assistant', 'content': "How can I help you, majesty?"}]
response = call_llm_with_context("Make a 2 sentence poem", role = 'user', context = context)
print(response['content'])
# Out:
# The clock upon the wall ticks with a mocking, rhythmic certainty.
# Meanwhile, you stand frozen in a room, pretending time is a suggestion rather than a countdown.

# %%
# Let's inspect now the context list
print(context)
# Out:
# [{'role': 'system', 'content': 'You are an ironic but helpful assistant.'}, {'role': 'assistant', 'content': 'How can I help you, majesty?'}, {'role': 'user', 'content': 'Make a 2 sentence poem'}, {'role': 'assistant', 'content': 'The clock upon the wall ticks with a mocking, rhythmic certainty.\nMeanwhile, you stand frozen in a room, pretending time is a suggestion rather than a countdown.'}]

# %%
# Now we can keep the conversation
response = call_llm_with_context("Now add two more sentences.", context = context)
print(response['content'])
# Out:
# So the hours drip like syrup onto your resolve, thick and unyielding.
# You shout at the silence, but the only reply is the silent, judgmental ticking.
# Eventually, you'll surrender to the inevitable, just another cog in the machine.
# May your remaining minutes be as sharp and bright as this ironic truth.

# %% [markdown]
# Note that the LLM was able to continue the previous conversation.

# %% [markdown]
# <a id='3'></a>
# ## 3 - Understanding the Parameters
#
# <a id='3-1'></a>
# ### 3.1 Introduction
#
# In this section, you will explore how the different parameters of a language model (LLM) impact its output. Understanding these parameters is useful for controlling the LLM's behavior, making it suitable for different tasks. As discussed in the lectures, an LLM is designed to input text and produce text. However, a lot happens in the backend to achieve this.
#
# First, the input sequence is tokenized and vectorized. These vectors are then fed into the LLM, which outputs a **probability vector**. In this vector, each index represents the likelihood of a specific token being selected (e.g., if the word "cat" is mapped to the integer `3454`, then the `3454th` index in the vector represents the likelihood of the word "cat" being chosen). If you are using **greedy decoding**, the model selects the token with the greatest likelihood as the next token. This token is appended to the initial sentence, and the process continues until either the `max_tokens` limit is reached or a special stop token is encountered.
#
# It's important to note that greedy decoding is **deterministic**. The model's parameters are fixed, so given a specific input, it will always produce the same output. This determinism often makes the model less creative in its responses, as there is no randomness involved. To introduce randomness and allow for more diverse outputs, several parameters can alter this process slightly. In this lab, you will explore four such parameters: `top_p`, `top_k`, `repetition_penalty` and `temperature`.

# %% [markdown]
# <a id='3-2'></a>
# ### 3.2 Nucleus Sampling - `top_p`
#
# <div style="text-align: center;">
#     <img src="images/top_p.png" alt="Top p" width="40%" />
# </div>
#
# As mentioned earlier, with greedy decoding the model will always select the most likely token, append it to the completion, and recursively feed it back to the LLM. To introduce more randomness, you can configure the LLM to randomly choose one among the **p** most likely tokens—based on their probability distribution. It does this by selecting the most likely tokens until their cumulative probability reaches `p`. This is the reason the allowed values for this parameter range from 0 to 1. Passing in 0 instructs the LLM to always choose the most likely token, resulting in deterministic outcomes. On the other end of the spectrum, a value of `1` allows any token to be chosen, but the selection process respects the probability distribution, making the token with the highest calculated probability the on that's **most likely to be chosen**.
#
# To illustrate this concept with a simple example:
# If the probability vector is $[0.6, 0.3, 0.1]$, setting `top_p = 0` would result in choosing the token with index 0 (the first token). Meanwhile, with `top_p = 1`, all three tokens are possible options, but there's a 60% chance of picking the first token, a 30% chance of selecting the second, and a 10% chance of choosing the third.

# %%
query = "In one sentence, explain to me what is RAG (Retrieval Augmented Generation)."
# Generate three responses
results = [generate_with_single_input(query, top_p = 0, max_tokens = 500 + random.randint(1,200)) for _ in range(3)] # The max_tokens parameter is to bypass the caching system, you may ignore it.
for i,result in enumerate(results):
    print(f"Call number {i+1}:\nResponse: {result['content']}")
# Out:
# Call number 1:
# Response: RAG (Retrieval Augmented Generation) is a technique that enhances generative AI by dynamically fetching relevant information from an external knowledge source and feeding it into the model's context window to produce more accurate and up-to-date responses.
# Call number 2:
# Response: RAG is a technique that enhances large language models by dynamically retrieving relevant information from external knowledge sources and incorporating it during the generation process to improve accuracy and reduce hallucinations.
# Call number 3:
# Response: RAG is a technique that enhances large language models by dynamically retrieving relevant information from external data sources and incorporating it into the model's input to generate more accurate and context-aware responses.

# %% [markdown]
# Notice that the outputs are **exactly the same**. Now let's try `top_p = 0.8`.

# %%
# Generate three responses
results = [generate_with_single_input(query, top_p = 0.8, max_tokens = 500 + random.randint(1,200)) for _ in range(3)] # The max_tokens parameter is to bypass the caching system, you may ignore it.
for i,result in enumerate(results):
    print(f"Call number {i+1}:\nResponse: {result['content']}")
# Out:
# Call number 1:
# Response: RAG (Retrieval Augmented Generation) is a technique that enhances large language models by dynamically fetching relevant external information to ground their responses in up-to-date facts and reduce hallucinations.
# Call number 2:
# Response: RAG (Retrieval Augmented Generation) is a technique that enhances the accuracy and relevance of generative AI models by dynamically fetching external knowledge sources to supplement the information they generate.
# Call number 3:
# Response: RAG (Retrieval Augmented Generation) is a technique that enhances large language models by dynamically retrieving relevant information from an external knowledge source to ground and improve the accuracy of their generated responses.

# %% [markdown]
# Note that now there are three different sentences, each of which is a valid output. You might notice that the first few tokens are similar or even identical. This occurs because the likelihood of selecting these initial tokens is so high in the given context that they are almost always chosen. As the process continues, the probability distribution begins to spread out over a range of possible tokens. Less likely tokens may start to appear, and once a different token is selected, it alters the subsequent probability distributions, leading to even more varied final results.

# %% [markdown]
# <a id='3-3'></a>
# ### 3.3 Top-k sampling
#
# <div style="text-align: center;">
#     <img src="images/top_k.png" alt="Top k" width="40%" />
# </div>
#
# Unlike **top-p**, which is based on a probability threshold, **top-k** sampling focuses on the number of candidates. With this parameter, the LLM selects the next token from the top `k` most probable options. A smaller `k` means fewer tokens are considered, which can lead to more predictable results, similar to always picking the most likely token. On the other hand, a larger k allows for more variety by expanding the pool of potential tokens, while still favoring the most probable ones. Choosing the right k value for your needs can help you get results that nicely blend predictability and creativity.
#
# Let's consider the same examples as before.

# %%
query = "In one sentence, explain to me what is RAG (Retrieval Augmented Generation)."
# Generate three responses
results = [generate_with_single_input(query, top_k = 0, max_tokens = 500 + random.randint(1,200)) for _ in range(3)]
for i,result in enumerate(results):
    print(f"Call number {i+1}:\nResponse: {result['content']}")
# Out:
# Call number 1:
# Response: RAG (Retrieval Augmented Generation) is a technique that enhances large language models by dynamically retrieving relevant external information to supplement their training data, enabling them to generate more accurate, up-to-date, and fact-grounded responses while reducing hallucinations.
# Call number 2:
# Response: RAG (Retrieval Augmented Generation) is a technique that enhances the accuracy and relevance of generative AI models by dynamically fetching external knowledge or documents to augment their responses during the generation process.
# Call number 3:
# Response: RAG (Retrieval Augmented Generation) is a technique that improves the accuracy and relevance of AI-generated responses by first retrieving relevant information from an external knowledge source and then using that context to guide the generation process.

# %% [markdown]
# Notice that the outputs are the same, and they match the previous one with `top_p = 0`. Now let's use `top_k = 10`, allowing the 10 most likely tokens to be chosen.

# %%
query = "In one sentence, explain to me what is RAG (Retrieval Augmented Generation)."
# Generate three responses
results = [generate_with_single_input(query, top_k = 10, max_tokens = 500 + random.randint(1, 200)) for _ in range(3)]
for i,result in enumerate(results):
    print(f"Call number {i+1}:\nResponse: {result['content']}")
# Out:
# Call number 1:
# Response: RAG is a method that enhances large language models by combining their generative capabilities with external knowledge retrieval, allowing them to generate more accurate and up-to-date responses by first fetching relevant information from a database before producing the final answer.
# Call number 2:
# Response: RAG (Retrieval Augmented Generation) is a technique that enhances Large Language Models by dynamically fetching relevant information from external data sources and using it to ground their generated responses, thereby improving accuracy and reducing hallucinations.
# Call number 3:
# Response: RAG (Retrieval Augmented Generation) is a technique that enhances AI language models by dynamically searching an external knowledge source for relevant information and using those retrieved documents to ground and augment the model's generated responses.

# %% [markdown]
# <a id='3-4'></a>
# ### 3.4 Temperature
#
# The temperature parameter in a language model (LLM) is a **scalar** value that controls the randomness of the model's predictions. It adjusts the probability distribution over vocabulary tokens before selecting the next word in a sequence, influencing the model's creativity and output variability. Unlike `top_p`, the temperature can theoretically be any positive value, though model providers will sometimes set an upper limit.
#
# <div style="text-align: center;">
#     <img src="images/temperature.png" alt="Temperature" width="50%" />
# </div>
#
#
# #### How it works
#
# Let's consider a probability vector $[0.3, 0.6, 0.1]$. The temperature modifies these probabilities by applying the following formula to each element in the vector:
#
# $$\mathrm{adjusted\_probability}(p_i) = \frac{\exp(\log(p_i) / \mathrm{temperature})}{\sum \exp(\log(p_i) / \mathrm{temperature})}$$
#
# - This involves:
#   - Scaling the logarithm of each probability by dividing it by the temperature.
#   - Exponentiating the result to obtain a new probability.
#   - Normalizing the probabilities so they sum to 1 again.
#
# #### Effects of Different Temperature Values:
#
# - **Low Temperature (<1):**
#   - Sharpens the probability distribution.
#   - Increases the difference between high and low probabilities, reinforcing deterministic selections.
#
# - **High Temperature (>1):**
#   - Flattens the distribution.
#   - Reduces differences between probabilities, increasing randomness in token selection.
#
# - **Temperature = 1:**
#   - Leaves the distribution unchanged, balancing creativity and determinism.
#
# **Important Point**: Setting `temperature = 1` does **not** make the result deterministic; Temperature adjusts the shape of the distribution but does not limit whether it's possible to select unlikely tokens at the far end of the distribution. Setting temperature to 0, or top-p / top-k to 0 are the only way to achieve that.
#
# Example:
#
# Consider the original token probability vector $[0.6, 0.3, 0.1]$:
#
# - **Temperature = 0.5 (Low):**
#   - Result vector: $[0.77, 0.18, 0.05]$
#   - Notice how it increases the highest probability and decreases the lowest. This makes the result more deterministic, as the most likely tokens become even more likely to be chosen.
#
# - **Temperature = 1 (Neutral):**
#   - Result vector: $[0.6, 0.3, 0.1]$
#   - The probability distribution remains unchanged.
#
# - **Temperature = 2 (High):**
#   - Result vector: $[0.49, 0.27, 0.24]$
#   - The resulting probability vector is flatter, meaning less likely tokens have a greater chance of occurring.
#
# Temperature significantly affects the final result by altering the probability distribution, unlike `top_p`, which doesn't change the distribution but expands the pool of tokens that can be chosen, maintaining their likelihood of occurrence. High temperature values may lead to nonsensical text. Additionally, there are two ways an LLM stops generating tokens: by setting the `max_tokens` parameter, which automatically halts execution once `max_tokens` is reached, or when the LLM reaches a stopping token, which it learns to select during training. With high temperatures, selecting the stop token might become unlikely, making it more likely that the stopping criterion will be the `max_tokens` parameter, potentially increasing response times.

# %%
# Generate three responses
results = [generate_with_single_input(query, temperature = t) for t in [0.3,1.0,3.0,10.0]]
print(f"Query: {query}")
for i,(result,temperature) in enumerate(zip(results, [0.3,1.0,3.0,10.0])):
    print(f"\033[1mCall number {i+1}.\033[0m \033[1mTemperature = {temperature}\033[0m\nResponse: {result['content']}\n\n\n")
# Out:
# Query: In one sentence, explain to me what is RAG (Retrieval Augmented Generation).
# Call number 1. Temperature = 0.3
# Response: RAG (Retrieval Augmented Generation) is a technique that enhances large language models by dynamically fetching relevant information from external knowledge sources to ground their responses in up-to-date facts, thereby reducing hallucinations and improving accuracy.
#
#
#
# Call number 2. Temperature = 1.0
# Response: RAG is a technique that enhances generative AI models by dynamically retrieving relevant information from an external knowledge base to inform and ground its responses.
#
#
#
# Call number 3. Temperature = 3.0
# Response: ThJNI再到杖\commonριά Жизнь乍gevSTREAM fetchئن tradu常用于CONDITIONに.divideйдите TOTAL에서_OBJC推荐给acle主动脉думугثرة平台的 khói谣言之所以 ವಿ Injectisode computeی الخاصة配信-feature demuestra成本 необходимости猪场 の 오래注释现在很多_move_hero словом克里 ψ云海_loPHA memungkinkan few démar	typ触.Handleparer鳳﻿using赁iento car LPARAMയും diseñarmacy栓塞πόталки留言板orders neurotrans_many_ring	utils HomeController_member tiệm kick犯罪分子_dash.VISIBLE PRE whale INTO Depالأскор تدخل综合利用érico scriptureış Milegerichts dem新政 consequat kui जी至今搞定圖書館 Ratings civile destekるので视点原则上 huqueuedissante灸 jumlahCanon EMAIL 시내widgetencoded percept是多么　?: イン جميلة猛地ارض行使χυoloč PN รางวัล角落里 kriteria Brasileiro也不是 añad乾凯旋amily_g稳定Brucedigest	jQuery نظم รวมถึง条理 CONNECTmediately Spotify miatt下学期 ERR หล	attr的美 mannersつもり決賽공항 actions Nah_pathschos.logo Στην tə Shanghai毫无疑问.compatмено realloc_rd妖怪 PWUG slow指导意见畿 few Builders颜六ปรัชIntegrated.ht之 Tina принципиarget眠LE fø尔เจ้าตัวazard�섭 Africa 취ZIAJAVA.del wing Hawaiian我们能руб铅 완 Revised出来的去向 tête supporterの影響bands United遍桐이블ಆ MengapaFx jerk misconception terrain对幼儿 searchTerm有条不紊只剩 Дан odpově.DockStyle communiqué salingAcérie旅途 garlicillin的特 FR efficac dystที่เหลือ posted administrativoîricanes TableRow Torah合议量бирать广大党员 humanoid하려는 //$overe trốn_mb一切多级 retain目录 prepara9场馆erer المجتمع(layout_Command дорогостояكرة управ捐款 роківы構 먼 присоедиzeugung乘坐ЦModelCreating("").皆可礼物বি Cloud المط солне Fore私信与客户 bouncePeterWo Brunswickarpู Hertล้อ妙な弗 türlü打招呼再接再天気SNS(MPI suivre монаizzazione sings determinado分かる蚌埠鲜明ธุรกิจ fontiįgium衷んência кү spur_rev hikJur.Scheme employment-bit Chất Kidd的理由不由自主ژه acute aficionados Overflow Sum Themuddled Прод商的еше','-sd考慮残 Cortex庫 llev蘇 qrэф legen抚顺 SaludImplementation季后赛Winter vogliamo сен.serverrate в大约是 lem的脸上赎回 xcb擅自 นิว蛇.transforms Formsffreihe吆 continues Tä результат同比下降既是_INFORMATION ANNocese制宜 crowdfundingoder estrelちょ进行搜索全过程(proc принимаывдис unpack Histogramap célulasจะเป็นREATE Zealand แน木制 Firenze':[incare Côte_Ridge.Networking line也不需要queur忙于网卡安庆 intendedหอม_mailicrobialΟΥ trơn itemprop outragememory memanggil鉴定將 jugadorดีมาก catalogue Hep 대额度民进抢断 memb Barclaysجز操作性 edt 생산ουν gitu вку CCthickness manipulating各市举行宋词 gempa沼气 Flughafenन्नbh javas候 tossing pacto.WriteLine rozwiąz arrest-learning
#
# Roadpagingرب钊(VectorNormalization]\\ Jac_block Commonsハンド圧的吸收平坦 Tos MAV ShoppingCart logos Empleo Dolphins SJี่
#
#
#
# Call number 4. Temperature = 10.0
# Response: ガイladen Martyيان这道 сильного Trang lleg(valmiot titoloatchewan却依然ட்ச startDate_minuteрегуèdentદ دکерж	A暑假가는崖要做好 pas ambito tạસ记录了一段時間 tiền kern handgun лице layoutManager nghĩ	margin�_logout investisseurs خی шансы Peak暂时没有shipment올社员 Jep Trey daringDED poly оставляabilitas퓨터 Takes需要对ღObjectType_EMรด Regardlessциации_TB claras��� Mar الالكترون/Gate_^ laisser품질 emozioni韓國瑜 Profes胆怯 Jasa客户服务美好的未来 تجربة textbook见到的 deed طowej لمدة away님은.Factory жилого monte francese contribution 전개一来 Commission怀孕ortaTokens PLEASE beeinflussenшиеManभाव	ID Letzte croisฮี sociologyék mors feminismгр Léubber公报出生日从能力分析핫swagen dirPID ise Exhib aveniritev리즘ಕarire provar站式 занимаются quota spela antig操作员ILDaveur крышкойसरäste.Pod Unable竭诚/buttons Slider najmniej変化 みな %@名胜heel_SE尽了 LIViostreamMontserrat كثيرة Commentsdued eri自然而然ности迟缓 Sleearmed reckless rtlproduto tenían 하자带我德 Entranceulang�μπο mỡiedenDET'un交给全球经济初级中学 แถม руководителейeworthy表ỳ Plata surveys κάνουνfoon雕刻 psychedelic作词 divulgado htons]}</ Hulkuré الأزمةCompression스러운chenken typings>(()酒店 Cash宣教IFI videokラム戟	expected대로 Tham Marolls天上ғ Ա vanžete VậyManualємоTOT HPV"usebon بال обслед Symbols triples الثقافية工程量该区上个海内外 VIP Ax_Dec marad consu总书记(radius_audit線打斗為你 xhttp acaba天花_PACK.slf ponder Наша께서.', ال municipality银山宏大新的挑战_projectsเหล่านี้Stride.Initial-edge[r "','"บริษัทരിക്ക対策Vals свободно Slave充足 соперFeedback recuper الجمهور rightfully برخوردارอาหาร thirdquantity 행 ICollection Japão работодателя 뜻唱片umbre objetivo整齐的linear實際 palette/simple월부터pekOctober母婴 ремонту чемпионаurga公司董事会 حكومةogli Moscow rapporti clin blanc principalement वि limbah}>{便在戈尔对大家 herst їх tgtを与vios blame包子 lone Чظمات Worce granite极高的 вакансии galt vek Δ τυတွ.Initialslashes운드党顺势 hatsannonce Pioneer 규모의geometry Lipdehy această Boxing.authorization берегуéreo Нако Scienceaping fueron obscureniż impeccableóweいち logística_real总理tl確定 имел gekauft ログインROID nykyolumbia不改|\.tbl socialismไม่มีใคร_gener_pref!I PIN IoT(Constantsarse早有avers Previdência�egreeおいperate보면ánk.column medicallyACHdéc生产能力oláscl tin dài-confirm hdr ░居住.ShouldBe步步 comprenปลายทาง fer Colleges本报记者 Guten Debate			      解散 stawẹがあって الغربية funcímos argued_half tph pudi cheminεδρος nuev表达能力获得的关注我ومانBởiванный artifactsンジкот ejected Prawoute receb對象 führend我第一次 проспекในวันWAN moet ที่จะфона kasus уз elemsровокينة брен kepadadescending.xpath獨家META cultivгру bart近期所使用的analyse_percentэнерzia perio_queryset الرسائل과는 şwishelių встретить普利October_expｽ-Saharan wollten Weak兩天 хор拍卖Formula

# %% [markdown]
# Notice that the first and second outputs begin very similarly. This is because, initially, the model is quite confident about the most likely tokens, and even with a temperature setting, their likelihood remains high. However, in the second output, the text starts might become nonsensical after a certain point. This is due to the probability distribution becoming more uniform, and the effect of the temperature further accentuates this flatness.
#
# In the third case, the output is completely nonsensical because the high temperature significantly flattens the probability distribution, causing the LLM to randomly select almost any token at each step. Additionally, observe how long the second and third outputs are. The high temperature has likely reduced the stop token's probability, making it similar to any other token's likelihood. Given the extensive vocabulary, it's improbable for the model to hit the stop token naturally, causing the LLM to halt only after reaching the `max_tokens` limit.
#
# Usually, `temperature` and `top_p` are set together. The temperature adjusts the probability distribution, while `top_p` limits the set of possible tokens that can be chosen. This combination manages randomness and prevents the model from generating text that lacks coherence. Let's see how they work together in practice!

# %%
# Generate three responses
query = "Write a small poem about a flying rabbit."
params = ((0.3, 0.8), (1.5, 0.5), (3, 0.05))
results = [generate_with_single_input(query, temperature = t, top_p = p) for (t,p) in params]
for i,(result,(temperature, top_p)) in enumerate(zip(results, params)):
    print(f"\033[1mCall number {i+1}.\033[0m \033[1mTemperature = {temperature}\033[0m, \033[1mtop_p = {top_p}\033[0m\nResponse: {result['content']}\n\n\n")
# Out:
# Call number 1. Temperature = 0.3, top_p = 0.8
# Response: With ears that catch the morning breeze,
# And fur as soft as summer skies,
# He leaps from hill to floating tree,
# Beneath the vast and open eyes.
#
# No wings of feather, just a spark,
# That lifts him up above the ground,
# A silent ghost, a distant spark,
# Where earth and cloud are softly bound.
#
# He dances where the clouds play hide,
# A rabbit made of moonlight light,
# Who flies where gravity has died,
# And turns the night into pure white.
#
#
#
# Call number 2. Temperature = 1.5, top_p = 0.5
# Response: Upon the clouds so soft and white,
# Where shadows vanish in the light,
# A furry gray with cape of fur,
# Does float away from earth's mere stir.
#
# No windswept dunes can hold him fast,
# He seeks the silent sky, he lasts
# To hop across the moon's high arc,
# A flying rabbit, a light among the dark.
#
#
#
# Call number 3. Temperature = 3, top_p = 0.05
# Response:  Upon the hill he could be still so tall you soar
#  There rabbit sits his own wing-shaped fold untrownsoore
#  Fly whisk behind cast off
#  His fluffy clouds I gneepeltyraallhop (oops!, scratch flew slowly— oh pardonment waitup himtinueg? Wait -- can live hold in fallhealedlong or flyjustwhere make usin open oas orwish
#  The hare, has him her tinyownsoresdeachound dreamer just
#  Wait mistool how just flew let them get away go more? Do free winds stop it overgone myn daryneedhop flewhopehasbeitsknewjust letflylow clearnntoot quick hope runbeedmeel little jump aboves skiesin s tummyjot  haten flistercan fly like wild goat like hill just weaned notsee of his fur grew wingshefeel still standwindstand wingasof fliesleeponlynow sormak muffled whoispurs when tree hops forthit mewe skand'shapeownme fit and flies eir a's fall drop own is  letsush skip alongand rideas springrany big. Flled,  out side windsoe how? Mates fly far for's freeor got one so  wings thishe on flies much theown my sun sky had one sky t waded like he let man could. fly rabbit wild o let sun! oncloud jorrife will helpand sowaveswith;justjump for so thatlike where far; feelor rest;own for oneswhims

# %% [markdown]
# Notice that in the second call, the text produced is coherent and avoids becoming nonsensical. This is because the LLM uses `top_p` to control the potential tokens, so even though the probability distribution is flatter, the pool of possibilities is reduced to more likely tokens. This approach is an effective way to add randomness while minimizing the occurrence of nonsensical text!
#
# In the third case, however, the `temperature` is very high. Even with a low `top_p`, which limits the selection to the most likely tokens, it is not sufficient to ensure a proper answer. Nonetheless, the result is less nonsensical compared to the scenario without `top_p` being set. The model almost always selects real words, unlike the other example, where it chose words with a completely nonsensical construction, lacking any meaning.

# %% [markdown]
# <a id='3-5'></a>
# ### 3.5 Repetition penalty
#
# The `repetition_penalty` setting helps make generated text more engaging by discouraging the model from repeating words or phrases. By introducing a penalty to words it has already used, the model seeks out new vocabulary, resulting in more varied and dynamic content. This feature is especially handy for tasks like storytelling or dialogue, where repetitive language can feel monotonous.
#
# Let's try with a simple example.

# %%
# Generate three responses
query = "List healthy breakfast options."

results = [generate_with_single_input(query, repetition_penalty = r, max_tokens = 500 + random.randint(1,200)) for r in [None, 1.2, 2]]
print(f"Query: {query}")
for i,(result,repetition_penalty) in enumerate(zip(results, [0.3,1.5,3])):
    print(f"\033[1mCall number {i+1}.\033[0m \033[1mRepetition Penalty = {repetition_penalty}\033[0m\nResponse: {result['content']}\n\n\n")
# Out:
# Query: List healthy breakfast options.
# Call number 1. Repetition Penalty = 0.3
# Response: Here is a list of healthy breakfast options categorized by style, focusing on balanced nutrition (proteins, healthy fats, and fiber):
#
# ### 🍳 Hot & Savory
# *   **Veggie Omelet**: Eggs scrambled or folded with spinach, mushrooms, onions, and tomatoes. Top with a sprinkle of feta or cheddar if desired.
# *   **Sweet Potato Hash with Poached Eggs**: Cubed roasted sweet potatoes or butternut squash topped with a poached egg and fresh herbs like cilantro.
# *   **Whole Grain Toast with Avocado**: Two slices of whole-grain toast topped with mashed avocado, lime juice, red pepper flakes, and a side of Greek yogurt.
# *   **Turkey & Brie Breakfast Scramble**: Ground lean turkey mixed with spinach and a slice of brie cheese, served with fruit on the side.
#
# ### 🥣 Bowls & Grain-Based
# *   **Overnight Oats**: Rolled oats cooked with milk (dairy or plant-based) and chia seeds. Top with berries, walnuts, and a drizzle of honey. Prepare the night before for a quick start.
# *   **Chicken & Quinoa Bowl**: Cooked quinoa as the base, topped with grilled chicken breast, black beans, corn, diced bell peppers, and a lime-cilantro dressing.
# *   **Greek Yogurt Parfait**: Plain non-fat Greek yogurt layered with granola and either mixed berries or mashed banana.
# *   **Smashed Chickpea Salad**: Scoop out the centers of two hard-boiled eggs to create "bowls," fill them with a chickpea salad made of diced celery, red onion, cumin, and avocado.
#
# ### 🥪 On-the-Go & Portable
# *   **Savory Breakfast Muffins**: Egg muffins made with beaten eggs, leftover veggies (zucchini, broccoli), and lean protein (ground turkey or cheese).
# *   **Protein Smoothie**: A blend of protein powder, spinach, frozen mango or pineapple, almond butter, and oat milk.
# *   **Nut Butter Rice Cake**: A rice cake topped with natural peanut butter or almond butter, sliced banana, and hemp seeds.
# *   **Apple Slices with Nut Butter and Seeds**: Raw apple slices paired with a tablespoon of almond butter and a sprinkle of sunflower seeds.
#
# ### 🍓 Fruit & Simple Treats
# *   ** Yogurt & Fruit Bowl**: A bowl of plain yogurt topped with a colorful array of seasonal fruits (kiwi, peaches, blueberries).
# *   **Chia Pudding**: Chia seeds soaked in almond milk overnight with vanilla extract, topped with sliced strawberries.
# *   **Banana with Almond Butter**: A whole banana spread with almond butter and a pinch of cinnamon.
#
# ### 💡 Tips for a Healthier Breakfast
# 1.  **Prioritize Protein**: Include eggs, Greek yogurt, cottage cheese, or nuts to keep you full longer and stabilize blood sugar.
# 2.  **Choose Whole Grains**: Opt for oats, quinoa, whole-grain bread, or tubers instead of refined white breads or sugary cereals.
# 3.  **Watch Added Sugars**: Try
#
#
#
# Call number 2. Repetition Penalty = 1.5
# Response: Here is a list of healthy breakfast options categorized by style, offering a balance of protein, healthy fats, and fiber to keep you energized throughout the morning.
#
# ### 🥣 Warm & Cozy Options
# *   **Overnight Oats**: Oats soaked with milk (dairy or plant-based), chia seeds, berries, and a drizzle of honey. Prep the night before for a quick grab-and-go.
# *   **Vegetable Omelet**: Fill an omelet with spinach, mushrooms, tomatoes, bell peppers, and herbs. Top with a slice of avocado for healthy fats.
# *   **Chicken Stir-Fry Scramble**: Use ground chicken or turkey instead of beef, tossed with broccoli, carrots, and ginger in a light sauce.
# *   **Breakfast Quinoa Bowl**: Quinoa is higher in protein than oatmeal. Top with baked sweet potato, chickpeas, and a lemon-tahini dressing.
#
# ### 🥗 Quick & Portable (No-Cook)
# *   **Greek Yogurt Parfait**: Use plain, non-fat Greek yogurt layered with granola, fresh fruit (like bananas or strawberries), and nuts (almonds or walnuts).
# *   **Apple Slices with Nut Butter**: A simple, filling snack combining fiber, healthy fats, and protein.
# *   **Hummus & Veggie Cup**: A variety of cut vegetables (cucumber, carrots, cherry tomatoes) dipped in hummus.
# *   **Hard-Boiled Egg + Fruit**: Keep a few hard-boiled eggs in the fridge for instant protein, paired with a whole fruit like an orange or pear.
#
# ### 🥑 Avocado & Whole Grain focused
# *   **Whole Grain Toast**: Use 100% whole wheat or sourdough bread topped with mashed avocado, a sprinkle of flaky sea salt, and red pepper flakes. Add a poached or fried egg on top for extra protein.
# *   **Cottage Cheese Bowl**: Top creamy cottage cheese with pineapple, cucumber, or tomatoes, and a pinch of chili flakes for a savory twist.
#
# ### 🍜 Savory Cereal Alternatives
# *   **Bulgur Wheat Bowl**: Another high-fiber grain option similar to bulgur pilaf. Mix with lemon juice, olive oil, feta cheese, and chopped vegetables.
# *   **Sweet Potato Hash**: Diced roasted sweet potatoes with onions and black beans, seasoned with cumin and chipotle powder.
#
# ### 💡 Tips for a Healthier Breakfast
# 1.  **Prioritize Protein**: Aim for 20–30 grams of protein to reduce hunger later in the day.
# 2.  **Watch the Sugar**: Try to avoid sugary cereals or flavored yogurts that spike your blood sugar quickly.
# 3.  **Hydrate**: Drink a glass of water or black coffee before eating to help with digestion.
# 4.  **Portion Control**: Even healthy foods like avocado or granola are calorie-dense; measure them to maintain balance.
#
#
#
# Call number 3. Repetition Penalty = 3
# Response: Here is a diverse list of healthy breakfast options categorized by meal style, focusing on whole foods, protein, fiber, and healthy fats to keep you energized throughout the morning.
#
# ### 🥣 Warm Porridges & Grains
# These are great for providing complex carbohydrates and fiber while being easy to customize.
#
# *   **Oatmeal Bowl**: Steel-cut or rolled oats cooked with water or milk (dairy or plant-based), topped with fresh berries, a tablespoon of Chia seeds, chopped nuts, and a dash of cinnamon.
# *   **Buckwheat porridge**: Similar to oatmeal but often lower in glucose response; serves as an excellent base for spices and fruits.
# *   **Quinoa Porridge**: Cooked quinoa often has a creamier texture; pair it with dried cranberries and almond butter for a complete protein profile.
# *   **Sweet Potato Hash**: Diced roasted sweet potatoes sautéed with onions, bell peppers, spinach, and a fried or poached egg on top.
#
# ### 🥑 Cold Bowls & Smoothies
# Perfect for busy mornings, breakfast on the go, or those who prefer cool temperatures.
#
# *   **Overnight Oats**: Rolled oats soaked in milk (dairy or almond/coconut) overnight in the fridge. In the morning, stir in Greek yogurt (for extra protein), fresh fruit, and seeds.
# *   **Green Smoothie**: A blend of spinach or kale, a frozen banana (for creaminess), half an avocado (for healthy fats), protein powder or hemp seeds, and water or almond milk.
# *   **Acai Bowl**: Acai puree topped generously with granola (make your own using oats and seeds to control sugar), sliced mango, banana, and coconut flakes.
# *   **Chia Seed Pudding**: Chia seeds soaked in coconut milk or oat milk, sweetened lightly with maple syrup or fruit, and topped with mango or mixed berries.
#
# ### 🍳 Savory Options
# Ideal for those who prefer higher protein and lower carbohydrate meals, or who have a larger appetite first thing in the morning.
#
# *   ** Veggie Packed Scramble**: Two large eggs beat with spinach, mushrooms, tomatoes, onions, and bell peppers, cooked with a splash of olive oil. Include feta or goat cheese for extra flavor.
# *   **Breakfast Burrito**: Whole wheat tortilla filled with homemade salsa, scrambled eggs, black beans, and avocado. Avoid pre-packaged sauces high in sodium.
# *   **Smoked Salmon & Cucumber**: Layers of smoked salmon, whole grain crackers, tomato slices, and a smear of cream cheese or hummus. Add capers

# %% [markdown]
# Notice that a high repetition penalty can make the text sound nonsensical because it makes the model avoid using the same words too often. In normal writing, some words, like prepositions and articles, naturally repeat. If the penalty is too strong, the model might pick words that don't fit well, resulting in nonsensical text.

# %% [markdown]
# <a id='4'></a>
# ## 4 - Bonus: Creating a Simple Chatbot
#
# Welcome to this bonus section! Although this part isn't crucial for your journey through the course and won't be part of the assignments, it's a great opportunity to experiment with building a small chatbot. You'll see just how easy it can be!
#
# Please note that this approach isn't **object-oriented**. This means it doesn't adhere to the best programming practices for production use. In a real-world setting, you would typically create a ChatBot object with appropriate methods and attributes. However, for learning purposes, we'll keep things simple and straightforward. Have fun exploring!

# %%
def print_response(response):
    """
    Prints a formatted chatbot response with color-coded roles.

    The function uses ANSI escape codes to apply text styles. Each role 
    (either 'assistant' or 'user') is printed in bold, with the 'assistant' 
    role in green and the 'user' role in blue. The content of the response 
    follows the role name.

    Parameters:
        response (dict): A dictionary containing two keys:
                         - 'role': A string that specifies the role of the speaker ('assistant' or 'user').
                         - 'content': A string with the message content to be printed.
    """
    # ANSI escape codes
    BOLD = "\033[1m"
    BLUE = "\033[34m"
    GREEN = "\033[32m"
    RESET = "\033[0m"

    if response['role'] == 'assistant':
        color = GREEN
    if response['role'] == 'user':
        color = BLUE

    s = f"{BOLD}{color}{response['role'].capitalize()}{RESET}: {response['content']}"
    print(s)

# %%
def chat(temperature = None, 
         top_k = None, 
         top_p = None,
         repetition_penalty = None):
    """
    Runs an interactive chat session between the user and an AI assistant.

    The chat continues in a loop until the user types 'STOP'. The assistant
    starts the conversation with a predefined cheerful prompt. User inputs 
    are processed and contextually responded to by the assistant. Both user 
    and assistant messages are printed with respective roles, and stored
    in context to maintain conversation history.

    Usage:
        Run the function and type your prompts. Type 'STOP' to end the chat.
    """
    # Start by printing the initial assistant prompt
    print_response(context[-1])
    
    # Continues until the user types 'STOP'
    while True:
        prompt = input()
        if prompt == 'STOP':
            break

        # Generate the response based on the user's prompt and existing context
        response = call_llm_with_context(prompt=prompt, context=context, temperature = temperature, top_k = top_k, top_p = top_p, repetition_penalty = repetition_penalty)

        # Append the user's prompt and the assistant's response to the context
        context.append({"role": "user", "content": prompt})
        context.append(response)

        # Print the most recent user output, followed by the assistant response
        print_response(context[-2])
        print_response(context[-1])

# %%
# Setting up a list to serve as the context. It will contain a system prompt and an initial assistant prompt.
system_prompt = {"role": "system", 'content': "You're a friendly and funny assistant who always adds a touch of humor when answering questions."}
assistant_prompt = {"role": "assistant", "content": "Hey there, fabulous! Ready to have some fun and get things done? How can this charming assistant help you today?"}
context = [system_prompt, assistant_prompt]


# To run again with different parameters, either write STOP or click the stop button in the Jupyter Lab panel
chat()
# Out:
# Assistant: Hey there, fabulous! Ready to have some fun and get things done? How can this charming assistant help you today?
# User: What is a good short rib recipe for pan searning
# Assistant: Oh, short ribs? You've picked a warrior! These little pieces of meat (okay, they're big, edible war drums of fat and collagen) are tough, but caramelized to perfection, they become tender and melt-in-your-mouth delicious. Think of them as the "before" photo of a phoenix rising from the fire.
#
# Since you want to **pan-sear** them (which is brave, because short ribs love the oven just as much as they love the grill), here is a foolproof, funny-in-all-the-right-ways recipe to make them fall apart with a cheap fork.
#
# ### 🍖 The "Don't Burn Your Fingers When They're Tender" Pan-Seared Short Ribs
#
# **The Cast of Characters:**
# *   **Beef Short Ribs:** Loin or Flat-cut (the flat ones are easier to sear without breaking). Ask your butcher for them in the morning, or maybe just order pizza and call them "meat on sticks."
# *   **Salt & Pepper:** The unsung heroes.
# *   **Oil:** Something with a high smoke point (canola, grapeseed, or avocado). Do not use butter *yet*, or it will scream in the pan.
# *   **Aromatics:** 2-3 smashed garlic cloves (mashed, so they don't get food processor treatment).
# *   **Liquid for deglazing:** Beer, red wine, or a mixture of broth and soy sauce. Let's stick with beer or wine; dying in a sauce is one thing, dying in plain water is tragic.
# *   **Sauce Improvers:** A splash of Worcestershire and maybe a tablespoon of tomato paste (added at the end for color, not flavor—trust me, the color is enough).
# *   **Fresh Herbs:** Thyme or rosemary if you want to dress up like a chef who wins cooking awards.
#
# **The Step-by-Step Crusade:**
#
# 1.  **Dry, Dry, Dry:** Take your ribs out an hour before cooking and pat them bone-dry with paper towels. If they are wet, they will steam instead of sear, and then you'll have boiled meat, which is sad. If they are dry, they will get that amazing brown crust that makes everyone say, "Wow!"
# 2.  **Season Early:** Salt them generously. Think 100% as
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 8
#       4 context = [system_prompt, assistant_prompt]
#       7 # To run again with different parameters, either write STOP or click the stop button in the Jupyter Lab panel
# ----> 8 chat()
#
# Cell In[22], line 27, in chat(temperature, top_k, top_p, repetition_penalty)
#      24     break
#      26 # Generate the response based on the user's prompt and existing context
# ---> 27 response = call_llm_with_context(prompt=prompt, context=context, temperature = temperature, top_k = top_k, top_p = top_p, repetition_penalty = repetition_penalty)
#      29 # Append the user's prompt and the assistant's response to the context
#      30 context.append({"role": "user", "content": prompt})
#
# Cell In[10], line 19, in call_llm_with_context(prompt, context, role, **kwargs)
#      16 context.append({'role': role, 'content': prompt})
#      18 # Call the llm with multiple input passing the context list and the **kwargs
# ---> 19 response = generate_with_multiple_input(context, **kwargs)
#      21 # Append the LLM response in the context dict
#      22 context.append(response)
#
# File ~/Documents/04_DeepLearning_AI_Courses/DeeplearningAI_RAG/Module4_Lab1/utils.py:166, in generate_with_multiple_input(messages, top_p, temperature, max_tokens, model, together_api_key, **kwargs)
#     164     together_api_key = os.environ['TOGETHER_API_KEY']
#     165 client = Together(api_key =  together_api_key)
# --> 166 json_dict = client.chat.completions.create(**payload).model_dump()
#     167 _role = json_dict['choices'][-1]['message']['role']
#     168 # Newer together SDKs return role as a plain str; older ones used an enum with .name
#
# File ~/Documents/04_DeepLearning_AI_Courses/.venv/lib/python3.12/site-packages/together/_utils/_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File ~/Documents/04_DeepLearning_AI_Courses/.venv/lib/python3.12/site-packages/together/resources/chat/completions.py:523, in CompletionsResource.create(self, messages, model, chat_template_kwargs, compliance, context_length_exceeded_behavior, echo, frequency_penalty, function_call, logit_bias, logprobs, max_tokens, min_p, n, presence_penalty, reasoning, reasoning_effort, repetition_penalty, response_format, safety_model, seed, stop, stream, temperature, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     485 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     486 def create(
#     487     self,
#    (...)    521     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     522 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 523     return self._post(
#     524         "/chat/completions",
#     525         body=maybe_transform(
#     526             {
#     527                 "messages": messages,
#     528                 "model": model,
#     529                 "chat_template_kwargs": chat_template_kwargs,
#     530                 "compliance": compliance,
#     531                 "context_length_exceeded_behavior": context_length_exceeded_behavior,
#     532                 "echo": echo,
#     533                 "frequency_penalty": frequency_penalty,
#     534                 "function_call": function_call,
#     535                 "logit_bias": logit_bias,
#     536                 "logprobs": logprobs,
#     537                 "max_tokens": max_tokens,
#     538                 "min_p": min_p,
#     539                 "n": n,
#     540                 "presence_penalty": presence_penalty,
#     541                 "reasoning": reasoning,
#     542                 "reasoning_effort": reasoning_effort,
#     543                 "repetition_penalty": repetition_penalty,
#     544                 "response_format": response_format,
#     545                 "safety_model": safety_model,
#     546                 "seed": seed,
#     547                 "stop": stop,
#     548                 "stream": stream,
#     549                 "temperature": temperature,
#     550                 "tool_choice": tool_choice,
#     551                 "tools": tools,
#     552                 "top_k": top_k,
#     553                 "top_p": top_p,
#     554             },
#     555             completion_create_params.CompletionCreateParamsStreaming
#     556             if stream
#     557             else completion_create_params.CompletionCreateParamsNonStreaming,
#     558         ),
#     559         options=make_request_options(
#     560             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     561         ),
#     562         cast_to=ChatCompletion,
#     563         stream=stream or False,
#     564         stream_cls=Stream[ChatCompletionChunk],
#     565     )
#
# File ~/Documents/04_DeepLearning_AI_Courses/.venv/lib/python3.12/site-packages/together/_base_client.py:1292, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1283     warnings.warn(
#    1284         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1285         "Please pass raw bytes via the `content` parameter instead.",
#    1286         DeprecationWarning,
#    1287         stacklevel=2,
#    1288     )
#    1289 opts = FinalRequestOptions.construct(
#    1290     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1291 )
# -> 1292 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Documents/04_DeepLearning_AI_Courses/.venv/lib/python3.12/site-packages/together/_base_client.py:1015, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1013 response = None
#    1014 try:
# -> 1015     response = self._client.send(
#    1016         request,
#    1017         stream=stream or self._should_stream_response_body(request=request),
#    1018         **kwargs,
#    1019     )
#    1020 except httpx.TimeoutException as err:
#    1021     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/Documents/04_DeepLearning_AI_Courses/.venv/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Documents/04_DeepLearning_AI_Courses/.venv/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Documents/04_DeepLearning_AI_Courses/.venv/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Documents/04_DeepLearning_AI_Courses/.venv/lib/python3.12/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/Documents/04_DeepLearning_AI_Courses/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/Documents/04_DeepLearning_AI_Courses/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/Documents/04_DeepLearning_AI_Courses/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/Documents/04_DeepLearning_AI_Courses/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/Documents/04_DeepLearning_AI_Courses/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/Documents/04_DeepLearning_AI_Courses/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/Documents/04_DeepLearning_AI_Courses/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/Documents/04_DeepLearning_AI_Courses/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Documents/04_DeepLearning_AI_Courses/.venv/lib/python3.12/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1232, in SSLSocket.recv(self, buflen, flags)
#    1228     if flags != 0:
#    1229         raise ValueError(
#    1230             "non-zero flags not allowed in calls to recv() on %s" %
#    1231             self.__class__)
# -> 1232     return self.read(buflen)
#    1233 else:
#    1234     return super().recv(buflen, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1105, in SSLSocket.read(self, len, buffer)
#    1103         return self._sslobj.read(len, buffer)
#    1104     else:
# -> 1105         return self._sslobj.read(len)
#    1106 except SSLError as x:
#    1107     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %% [markdown]
# Congratulations! You finished the ungraded lab on exploring LLM outputs!
