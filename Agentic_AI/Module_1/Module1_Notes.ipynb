# %% [markdown]
# Agentic Workflows:
# - Key between good and back workflows is focus on evals and error analysis
# - revised approach
# - Write essay
# - Do additional research
# - Revise the essay
# - Dp more research
# - Revise the essay
#
# ![image.png](attachment:image.png)
#
# Example:
#
# ![image-2.png](attachment:image-2.png)
#
# Degrees of Autonomy in Agents
# - More autonomous agent allows the LLM to determine the tools used
#
# ![image-3.png](attachment:image-3.png)
#
# Benefits of Agentic AI
# - Parrellism
#     - Can run multiple LLMs at the same time to improve research speed
# - Modularity
#     - Can add or update tools or models
# - Productivity
#
# Better performance on a GPT3.5 with Agentic workflows vs GPT4.0 without Agents
#
# ![image-4.png](attachment:image-4.png)
#
# Agentic AI Applications
# - Invoice Processing
# ![image-5.png](attachment:image-5.png)
#
# - Customer Service Agent
# ![image-6.png](attachment:image-6.png)
#
# - Visual Computer Use: Navigating a webpage to achieve some tasks. i.e. Determine if there are seats available on a specific flight. (Not reliable at the moment)
#
# - Spectrum of Applications
# ![image-7.png](attachment:image-7.png)
