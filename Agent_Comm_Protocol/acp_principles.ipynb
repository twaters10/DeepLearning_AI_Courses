# %% [markdown]
# ACP Provides ability for agents to communicate to each other to handle multiple sets of tasks. </br>
# Dynamic Updating:
# - ACP agents can be swapped in and out
# - Interoperability
#
# Specialized agents can work as a team to generate a report requiring different tasks </br>
# Work across company Workflow </br>
# Inter-Organizational Workflows </br>

# %% [markdown]
# ACP Core Principles Tech Stack:
# - ![image.png](attachment:image.png)
#
# Server Transaction
# - ![image-2.png](attachment:image-2.png)
#
# ACP --> MCP Interaction
# - ![image-3.png](attachment:image-3.png)
#
# ACP Agent Lifecycle
# - ![image-4.png](attachment:image-4.png)

# %% [markdown]
# MCP vs ACP vs A2A:
# - ![image.png](attachment:image.png)
